# %%
import pandas as pd
import numpy as np  
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\giftt\Downloads\Breast_cancer_dataset.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.all()
# Out:
# id                          True
# diagnosis                   True
# radius_mean                 True
# texture_mean                True
# perimeter_mean              True
# area_mean                   True
# smoothness_mean             True
# compactness_mean            True
# concavity_mean             False
# concave points_mean        False
# symmetry_mean               True
# fractal_dimension_mean      True
# radius_se                   True
# texture_se                  True
# perimeter_se                True
# area_se                     True
# smoothness_se               True
# compactness_se              True
# concavity_se               False
# concave points_se          False
# symmetry_se                 True
# fractal_dimension_se        True
# radius_worst                True
# texture_worst               True
# perimeter_worst             True
# area_worst                  True
# smoothness_worst            True
# compactness_worst           True
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# Diagnosis distribution
sns.countplot(x='diagnosis', data=df)
plt.title('Diagnosis Distribution')
plt.show()

# Convert diagnosis to binary
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})

# Correlation heatmap
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), cmap='coolwarm', annot=False)
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
import numpy as np
from scipy.stats import ttest_ind

# Compare means of features between malignant and benign
malignant = df[df['diagnosis'] == 1]
benign = df[df['diagnosis'] == 0]

ttest_results = {}
for column in X.columns:
    stat, p = ttest_ind(malignant[column], benign[column])
    ttest_results[column] = p

# Display features with significant differences
significant_features = [k for k, v in ttest_results.items() if v < 0.05]
print("Significant features:", significant_features)
# Out:
# Significant features: ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'radius_se', 'perimeter_se', 'area_se', 'compactness_se', 'concavity_se', 'concave points_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.impute import SimpleImputer

# Impute missing values in X_scaled
imputer = SimpleImputer(strategy='mean')
X_scaled_imputed = imputer.fit_transform(X_scaled)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled_imputed, y, test_size=0.2, random_state=42)

# Train model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[70  1]
#  [ 2 41]]
#               precision    recall  f1-score   support
#
#            B       0.97      0.99      0.98        71
#            M       0.98      0.95      0.96        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
# c:\Users\giftt\anaconda3\Lib\site-packages\sklearn\impute\_base.py:635: UserWarning: Skipping features without any observed values: [31]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
# Visualize top features by coefficient
feature_columns = X.columns.drop('Unnamed: 32')
coefficients = pd.Series(model.coef_[0], index=feature_columns)
top_features = coefficients.abs().sort_values(ascending=False).head(10)

top_features.plot(kind='barh')
plt.title('Top 10 Influential Features')
plt.xlabel('Coefficient Magnitude')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# Train-test split using imputed data
X_train, X_test, y_train, y_test = train_test_split(X_scaled_imputed, y, test_size=0.2, random_state=42)

# Train model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Evaluation
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[70  1]
#  [ 2 41]]
#               precision    recall  f1-score   support
#
#            B       0.97      0.99      0.98        71
#            M       0.98      0.95      0.96        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
# Visualize top coefficients
coefficients = pd.Series(model.coef_[0], index=feature_columns)
top_features = coefficients.abs().sort_values(ascending=False).head(10)

top_features.plot(kind='barh', color='teal')
plt.title('Top 10 Influential Features')
plt.xlabel('Coefficient Magnitude')
plt.show()

# %% [markdown]
# #This analysis demonstrates how diagnostic features from breast tissue samples can be used to predict tumor malignancy. Logistic Regression achieved high accuracy, and features like radius_mean, concavity_mean, and area_worst were among the most influential. This project showcases end-to-end data science workflow—from cleaning and EDA to modeling and interpretation.

# %% [markdown]
#  Making Predictions with Your Mode

# %%
# Predict class labels
y_pred = model.predict(X_test)

# Predict probabilities
y_proba = model.predict_proba(X_test)[:, 1]  # Probability of being malignant

# %%
#Evaluate Prediction

from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, pos_label='M'))
print("Recall:", recall_score(y_test, y_pred, pos_label='M'))
print("AUC Score:", roc_auc_score(y_test, y_proba))
# Out:
# Accuracy: 0.9736842105263158
# Precision: 0.9761904761904762
# Recall: 0.9534883720930233
# AUC Score: 0.99737962659679

# %% [markdown]
# - Accuracy: Overall correctness of predictions
# - Precision: How many predicted malignant cases were actually malignant
# - Recall: How many actual malignant cases were correctly identified
# - AUC: How well the model separates benign from malignant cases

# %%
#confusion_matrix(y_test, y_pred)

import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malignant'], yticklabels=['Benign', 'Malignant'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import roc_curve

# Specify pos_label since y_test contains 'B' and 'M'
fpr, tpr, thresholds = roc_curve(y_test, y_proba, pos_label='M')
plt.plot(fpr, tpr, label='Logistic Regression')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
# This analysis demonstrates how diagnostic features from breast tissue samples can be used to predict tumor malignancy. Logistic Regression achieved high accuracy, and features like radius_mean, concavity_mean, and area_worst were among the most influential. This project showcases end-to-end data science workflow—from cleaning and EDA to modeling and interpretation.
# Evaluate Prediction

# %%
# Example new data (replace with actual values)
# Prepend a dummy value for 'id' to match feature_columns length
new_sample_values = [0] + [17.99, 10.38, 122.8, 1001.0, 0.1184, 0.2776, 0.3001, 0.1471, 0.2419, 0.07871,
                           1.095, 0.9053, 8.589, 153.4, 0.006399, 0.04904, 0.05373, 0.01587, 0.03003, 0.006193,
                           25.38, 17.33, 184.6, 2019.0, 0.1622, 0.6656, 0.7119, 0.2654, 0.4601, 0.1189]

# Prepare a DataFrame with all columns as in X
new_sample_df = pd.DataFrame([new_sample_values], columns=feature_columns)

# If your scaler was fit on X (which includes 'id' and 'Unnamed: 32'), add those columns if missing
for col in X.columns:
    if col not in new_sample_df.columns:
        new_sample_df[col] = np.nan

# Reorder columns to match X
new_sample_df = new_sample_df[X.columns]

# Scale the new sample
new_sample_scaled = scaler.transform(new_sample_df)

# Impute missing values if needed
new_sample_scaled_imputed = imputer.transform(new_sample_scaled)

# Predict
prediction = model.predict(new_sample_scaled_imputed)
probability = model.predict_proba(new_sample_scaled_imputed)[0][1]

print("Prediction:", "Malignant" if prediction[0] == 1 else "Benign")
print("Probability of malignancy:", round(probability * 100, 2), "%")
import seaborn as sns
# Out:
# Prediction: Benign
# Probability of malignancy: 100.0 %
# c:\Users\giftt\anaconda3\Lib\site-packages\sklearn\impute\_base.py:635: UserWarning: Skipping features without any observed values: [31]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
import numpy as np

# Simulated patient samples (30 features each)
samples = np.array([
    # Likely benign
    [12.3, 14.2, 78.8, 465.0, 0.089, 0.045, 0.030, 0.020, 0.180, 0.055,
     0.45, 1.2, 3.0, 35.0, 0.005, 0.020, 0.015, 0.010, 0.020, 0.004,
     14.0, 16.0, 90.0, 600.0, 0.095, 0.050, 0.040, 0.025, 0.200, 0.060],

    # Borderline case
    [15.5, 18.0, 100.0, 700.0, 0.105, 0.080, 0.070, 0.050, 0.220, 0.070,
     0.80, 1.5, 5.0, 80.0, 0.007, 0.030, 0.025, 0.015, 0.030, 0.005,
     18.0, 20.0, 120.0, 900.0, 0.120, 0.090, 0.080, 0.060, 0.250, 0.080],

    # Likely malignant
    [20.0, 22.5, 140.0, 1200.0, 0.150, 0.250, 0.300, 0.200, 0.300, 0.100,
     1.5, 2.5, 10.0, 180.0, 0.010, 0.050, 0.045, 0.030, 0.050, 0.010,
     25.0, 28.0, 180.0, 2000.0, 0.180, 0.300, 0.350, 0.250, 0.400, 0.120]
])

# %%
# Prepend np.nan for 'id' to each sample to match feature_columns length
samples_with_id = np.hstack([np.full((samples.shape[0], 1), np.nan), samples])
samples_df = pd.DataFrame(samples_with_id, columns=feature_columns)

# If any columns are missing, add them as NaN
for col in feature_columns:
    if col not in samples_df.columns:
        samples_df[col] = np.nan

# Ensure 'Unnamed: 32' is present and filled with NaN
if 'Unnamed: 32' not in samples_df.columns:
    samples_df['Unnamed: 32'] = np.nan

# Reorder columns to match scaler/model input
samples_df = samples_df[list(feature_columns) + ['Unnamed: 32']]

# Scale and impute
samples_scaled = scaler.transform(samples_df)
samples_scaled_imputed = imputer.transform(samples_scaled)

# Predict
predictions = model.predict(samples_scaled_imputed)
probabilities = model.predict_proba(samples_scaled_imputed)[:, 1]

# Display results
for i, (pred, prob) in enumerate(zip(predictions, probabilities), 1):
    print(f"Patient {i}:")
    print("  Prediction:", "Malignant" if pred == 1 else "Benign")
    print("  Probability of malignancy:", round(prob * 100, 2), "%\n")
# Out:
# Patient 1:
#   Prediction: Benign
#   Probability of malignancy: 0.0 %
#
# Patient 2:
#   Prediction: Benign
#   Probability of malignancy: 19.69 %
#
# Patient 3:
#   Prediction: Benign
#   Probability of malignancy: 100.0 %
# c:\Users\giftt\anaconda3\Lib\site-packages\sklearn\impute\_base.py:635: UserWarning: Skipping features without any observed values: [31]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
